# %%
from qiskit import QuantumCircuit
from classical_to_quantum.applications.graph.graph_problem import GraphProblem

# %%
qc = QuantumCircuit(4, 4)
qc.h(0)
qc.h(1)
qc.h(2)

qc.x([0,1,2])
qc.mcx([0,1,2],3)
qc.x([0,1,2])

qc.u(theta=0, phi=0.02, lam=0.03, qubit=3)

qc.x([0,1,2])
qc.mcx([0,1,2],3)
qc.x([0,1,2])

qc.h([0,1,2])

qc.barrier()
qc.measure([0,1,2,3], [0,1,2,3])

qc.draw()

# %%
from qiskit.primitives import Sampler
sampler = Sampler()

result = sampler.run(qc).result()
print(result)
# Out:
# SamplerResult(quasi_dists=[{0: 0.999726619461398, 1: 3.9054362657e-05, 2: 3.9054362657e-05, 3: 3.9054362657e-05, 4: 3.9054362657e-05, 5: 3.9054362657e-05, 6: 3.9054362657e-05, 7: 3.9054362657e-05}], metadata=[{}])

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 from classical_to_quantum.applications.graph.grover_applications.test_grover_graphs import *
#       2 prep = graph_color_prep(variable_qubits)
#       3 oracle = graph_color_oracle(disagree_list, variable_qubits, check_qubits, output_qubit)
#
# File ~/workspace/quantum-journey2/classical_to_quantum/applications/graph/grover_applications/test_grover_graphs.py:2
#       1 import unittest
# ----> 2 from graph_color import *
#       3 from qiskit.quantum_info import Statevector
#       5 class MyTestCase(unittest.TestCase):
#
# ModuleNotFoundError: No module named 'graph_color'

# %%
plot_results(results, check_disagreement)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 plot_results(results, check_disagreement)
#
# Cell In[27], line 172, in plot_results(result, satisfies_disagree_list)
#     166         ax.containers[i][0].set(color='blue')
#     168 leg = plot.legend(['Incorrect (' + str(len(states) - correct_count) + ' counted)',
#     169                    'Correct (' + str(correct_count) + ' counted)'],
#     170                   fontsize='x-large',
#     171                   loc='upper left')
# --> 172 leg.legendHandles[0].set_color('blue')
#     173 leg.legendHandles[1].set_color('orange')
#     174 display(plot)
#
# AttributeError: 'Legend' object has no attribute 'legendHandles'
